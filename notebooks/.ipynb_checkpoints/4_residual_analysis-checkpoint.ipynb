# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
from functools import reduce
#import plotly as pl
import matplotlib 
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 300
matplotlib.rcParams["figure.dpi"] = 100

mag = ['B', 'V', 'I','J','H','K']; 
bands = ['M_B', 'M_V', 'M_I', 'M_J', 'M_H', 'M_K']; band = len(bands);
ap_bands = ['B_mag', 'V_mag' ,'I_mag', 'J_mag', 'H_mag', 'K_mag']
col_dot = ['b.', 'g*', 'y+', 'r*', 'c+', 'g.', 'y+', 'b+'] ; 
col_lin = ['b-', 'g-', 'y-', 'r-', 'c-', 'g-', 'y-', 'b-'] ; 
col_das = ['b--', 'g--', 'y--', 'r--', 'c--', 'g--', 'y--', 'b--']
col_ = ['b', 'g', 'y', 'r', 'c', 'g', 'y', 'b'] ; 
ls = ['BV', 'BI', 'BK', 'VI','VJ','VK','IJ', 'IH', 'IK', 'JH', 'JK', 'HK']
color_index = []
for i in range(0,6):
    for j in range(i+1,6):
        color_index.append(mag[i]+mag[j])

disg = '_g'

data_path = './data/'
# function for saving plots
def save(title, img_path = '../../../master_thesis/Latex/figures/clean/'):
    plt.savefig('%s%s.pdf'%(img_path,title))

def plot_corr(df, Y, title, s=0, f=12):
    # To visualize first row of seaborn pairplot
    plt.figure()
    sns.set_context("paper", rc={"axes.labelsize":f})
    sns.pairplot(data=df, x_vars=df.columns[::], y_vars=Y, kind = 'scatter')
    if s==1:
        save(title)
    plt.show()

def plot_pair(data_arr, title, s=0):
    plt.figure()
    g = sns.PairGrid(data_arr)
    g.map_upper(sns.scatterplot)
    g.map_lower(sns.kdeplot)
    g.map_diag(sns.kdeplot, lw=3, legend=False)
    if s==1:
        save(title)
    plt.show()
    plt.figure()
    sns.heatmap(data.select_dtypes(include = 'number').corr(), annot=True)
    if s==1:
        save('heat%s'%(title))
    plt.savefig()
    plt.show()
    
def regression(x, y, x_str, y_str, p = 0):
    regression_line = stats.linregress(x, y); 
    m = regression_line.slope; 
    c = regression_line.intercept
    prediction = m * x + c; 
    residue = y-prediction 
    m_error = regression_line.stderr; 
    c_error = regression_line.intercept_stderr
    if p == 1:
        print('%s = %f %s ( %f) + %f ( %f)'%(y_str, m, x_str, m_error, c, c_error))
    return m, c, prediction, residue, m_error, c_error

def plot(x_data, y_data, x_axis_str, y_axis_str, index=0, y_invert_flag_1=0, s=0):
    slope, intercept, prediction, residue, slope_error, intercept_error = regression(x_data, y_data, x_axis_str, y_axis_str)
#    intercept, slope, prediction, residue, slope_error, intercept_error = regression(x_data, y_data, nil1, nil2, x_name, y_name)
    fig, [ax1, ax2] = plt.subplots(figsize=(7,6), nrows=2, ncols = 1, sharex=True, gridspec_kw={'height_ratios':[2,1]})
    ax1.scatter(x_data, y_data , c = raw['EBV'])
    ax1.plot(x_data, prediction , col_lin[index], label = '%s = %f ($\pm$ %f) %s + %f ($\pm$ %f)'%(y_axis_str, slope, slope_error, x_axis_str, intercept, intercept_error))
    ax1.plot(x_data, prediction - y_data.std(), col_das[index], label = ' $\sigma$ = %f'%(y_data.std()))
    ax1.plot(x_data, prediction + y_data.std(), col_das[index]) # line of standard deviation
    ax1.set_xlabel('$\Delta$' + x_axis_str);    ax1.set_ylabel('$\Delta$' + y_axis_str);							
    ax1.legend(loc='upper left')
    if y_invert_flag_1 == 1:                                    # if flag value given in input, then only invert y-axis
        ax1.invert_yaxis()
    ax2.scatter(x_data, residue, label = 'slope $%s$: %f'%(bands[index], slope), c = raw['EBV']);  	
    ax2.legend()
    ax2.set_xlabel('$\Delta$' + x_axis_str); ax2.set_ylabel('Deviation from model line')
    ax2.axhline(y=0, color='r', linestyle='--'); ax2.axvline(x=0, color='r', linestyle='--'); 		
    if s==1:
        save(y_axis_str + x_axis_str)
    plt.show()
    return slope, intercept, prediction, residue, slope_error, intercept_error

# %%
#-------------------------------------------------------#
#                     Extinction                        #
#-------------------------------------------------------#
                                                        #Adopting extinction values from Foque(2007) - Table 4
Ab_v = 1.31                                             #          = A_b / A_v
Av_v = 1                                                #          = A_v / A_v
Ai_v = 0.608                                            #          = A_i / A_v
Aj_v = 0.292                                            #          = A_j / A_v
Ah_v = 0.181                                            #          = A_h / A_v
Ak_v = 0.119                                            #          = A_k / A_v
#---------------------------------------------------------------------------------#
#Ratio of total to selective absorption - driving wavelength dependent value of R #
#---------------------------------------------------------------------------------#
R_v = 3.23                                              #      R_V = A_v / E(B-V) 
R_b = Ab_v*R_v                                          #      R_B = (A_b / A_v) * (A_v / E(B-V)) 
R_i = Ai_v*R_v                                          #          = (A_i / A_v) * (A_v / E(B-V)) 
R_j = Aj_v*R_v                                          #          = (A_j / A_v) * (A_v / E(B-V)) 
R_h = Ah_v*R_v                                          #          = (A_h / A_v) * (A_v / E(B-V)) 
R_k = Ak_v*R_v                                          #          = (A_k / A_v) * (A_v / E(B-V))    

A = [Ab_v, Av_v, Ai_v, Aj_v, Ah_v, Ak_v]; 
R = [R_b, R_v, R_i, R_j, R_h, R_k]; 

print('Reddening Ratio with respect to E(B-V): \n Rb, Rv, Ri, Rj, Rh, Rk:', R)
# Out:
# Reddening Ratio with respect to E(B-V):
#  Rb, Rv, Ri, Rj, Rh, Rk: [4.2313, 3.23, 1.96384, 0.9431599999999999, 0.58463, 0.38437]

# %%
raw = pd.read_csv('./data/95_outlier_from_color.csv')
raw.info()
cepheid = len(raw)
mode = 'gaia'
#raw = pd.read_csv('.%s%s_apparent.csv'%(data_path,n_cepheid))
data = pd.read_csv('%s%s_absolute_IRSB_%s.csv'%(data_path,cepheid,mode))
w = pd.read_csv('%s%s_wesenheit_IRSB_%s.csv'%(data_path,cepheid,mode))
prediction = pd.read_csv('%s%s_prediction.csv'%(data_path,cepheid))
residue = pd.read_csv('%s%s_residue.csv'%(data_path,cepheid))
PLW = pd.read_csv('%s%s_PLW_slope_intercept.csv'%(data_path,cepheid))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  95 non-null     int64
#  1   level_0     95 non-null     int64
#  2   index       95 non-null     int64
#  3   ID          95 non-null     object
#  4   logP        95 non-null     float64
#  5   mM0_IRSB    95 non-null     float64
#  6   mMplx       95 non-null     float64
#  7   EBV         95 non-null     float64
#  8   B_mag       95 non-null     float64
#  9   V_mag       95 non-null     float64
#  10  I_mag       95 non-null     float64
#  11  J_mag       95 non-null     float64
#  12  H_mag       95 non-null     float64
#  13  K_mag       95 non-null     float64
#  14  DR3Name     95 non-null     object
#  15  Gmag        95 non-null     float64
#  16  BPmag       95 non-null     float64
#  17  RPmag       95 non-null     float64
#  18  RA_ICRS     95 non-null     float64
#  19  DE_ICRS     95 non-null     float64
# dtypes: float64(15), int64(3), object(2)
# memory usage: 15.0+ KB

# %%
def del_del(col, f='S'): 
    #input a reference wesenheit color, this function represents the delta delta plot. 
    del_res_WM = pd.DataFrame()
    del_pre_WM = pd.DataFrame()
    del_pre_WM['name'] = del_res_WM['name'] = data['name']
    del_mg = []
    del_cg = [] 
    del_meg = []
    del_ceg = []
    del_name = []
    for i in range(0,6):
        if f =='S':
            wesen = mag[i]+col
        else: 
            wesen = col[0]+col
        mg, cg, prg, reg , mrg, crg = regression(residue['r_'+wesen+disg], residue['r_'+mag[i]+disg], wesen, mag[i]+disg,1) 
        del_name.append(mag[i]+wesen)
        del_mg.append(mg)
        del_cg.append(cg)
        del_meg.append(mrg)
        del_ceg.append(crg)
        del_res_WM[mag[i]+wesen+disg] = reg
        del_pre_WM[mag[i]+wesen+disg] = prg
    del_slope_interecept = pd.DataFrame({'name': del_name, 
                                         'mg': del_mg, 'cg': del_cg, 
                                         'err_mg': del_meg,'err_cg': del_ceg})
    return del_res_WM, del_pre_WM, del_slope_interecept 

def del_col(ls=['BV', 'VI'], s=0):
    dres = pd.DataFrame()
    dpre = pd.DataFrame()
    dres['name'] = dpre['name'] = data['name']
    dmc = []
    for i in ls:
        a,b,c = del_del(i)
        dres = pd.merge(dres,a, on='name')
        dpre= pd.merge(dpre,b, on='name')
        dmc.append(c)
        x,y,z= del_del(i, i[0])
        dres = pd.merge(dres,x, on='name', suffixes=('', '_y'))
        dpre = pd.merge(dpre,y, on='name', suffixes=('', '_y'))
        dmc.append(z)
    del_mc = pd.concat(dmc, axis = 0, join = 'inner', ignore_index=True)
    del_mc = del_mc.drop_duplicates().set_index('name').T
    #del_mc =del_mc.T
    print('There will be %i relations, 12 for %i color minus duplicates.'%((6)*len(dmc), len(ls)))
    if s==1:
        x = len(dres)
        del_mc.to_csv('%s%i_del_slope_intercept.csv'%(data_path,cepheid))
        dres.to_csv('%s%i_del_res.csv'%(data_path,cepheid))
        dpre.to_csv('%s%i_del_pre.csv'%(data_path,cepheid))
    return dres, dpre, del_mc

cols=['VI', 'VK', 'IH', 'JK']
dres,dpre,del_mc = del_col(cols, s = 0)
# Out:
# B_g = 0.797956 BVI ( 0.077717) + 0.000000 ( 0.021622)
# V_g = 0.849508 VVI ( 0.060454) + -0.000000 ( 0.016552)
# I_g = 0.908501 IVI ( 0.036756) + -0.000000 ( 0.010064)
# J_g = 0.977134 JVI ( 0.019786) + -0.000000 ( 0.004956)
# H_g = 0.984627 HVI ( 0.012834) + -0.000000 ( 0.003071)
# K_g = 0.992178 KVI ( 0.008549) + -0.000000 ( 0.002025)
# B_g = 0.787008 VVI ( 0.081522) + 0.000000 ( 0.022320)
# V_g = 0.849508 VVI ( 0.060454) + -0.000000 ( 0.016552)
# I_g = 0.908501 VVI ( 0.036756) + -0.000000 ( 0.010064)
# J_g = 0.843314 VVI ( 0.035688) + -0.000000 ( 0.009771)
# H_g = 0.808435 VVI ( 0.032532) + -0.000000 ( 0.008907)
# K_g = 0.799338 VVI ( 0.033288) + 0.000000 ( 0.009114)
# B_g = 1.047182 BVK ( 0.086183) + 0.000000 ( 0.019634)
# V_g = 1.034064 VVK ( 0.063983) + -0.000000 ( 0.014989)
# I_g = 1.028415 IVK ( 0.037105) + -0.000000 ( 0.009099)
# J_g = 1.015208 JVK ( 0.018036) + -0.000000 ( 0.004367)
# H_g = 1.005661 HVK ( 0.011564) + -0.000000 ( 0.002714)
# K_g = 1.004054 KVK ( 0.007614) + 0.000000 ( 0.001784)
# B_g = 0.971860 VVK ( 0.089548) + 0.000000 ( 0.020978)
# V_g = 1.034064 VVK ( 0.063983) + -0.000000 ( 0.014989)
# I_g = 1.053086 VVK ( 0.045204) + -0.000000 ( 0.010590)
# J_g = 1.039842 VVK ( 0.023634) + -0.000000 ( 0.005537)
# H_g = 1.004815 VVK ( 0.013726) + -0.000000 ( 0.003216)
# K_g = 1.004054 VVK ( 0.007614) + 0.000000 ( 0.001784)
# B_g = 0.777834 BIH ( 0.102345) + 0.000000 ( 0.024805)
# V_g = 0.903533 VIH ( 0.082009) + 0.000000 ( 0.019266)
# I_g = 1.041163 IIH ( 0.050648) + -0.000000 ( 0.011759)
# J_g = 1.022225 JIH ( 0.023692) + 0.000000 ( 0.005641)
# H_g = 1.012254 HIH ( 0.015078) + -0.000000 ( 0.003501)
# K_g = 1.010654 KIH ( 0.009880) + 0.000000 ( 0.002295)
# B_g = 0.956111 IIH ( 0.093140) + 0.000000 ( 0.021624)
# V_g = 1.025596 IIH ( 0.067558) + 0.000000 ( 0.015685)
# I_g = 1.041163 IIH ( 0.050648) + -0.000000 ( 0.011759)
# J_g = 1.042838 IIH ( 0.026692) + 0.000000 ( 0.006197)
# H_g = 1.012254 IIH ( 0.015078) + -0.000000 ( 0.003501)
# K_g = 1.004987 IIH ( 0.015344) + 0.000000 ( 0.003562)
# B_g = 0.560898 BJK ( 0.118750) + 0.000000 ( 0.028363)
# V_g = 0.788353 VJK ( 0.100022) + -0.000000 ( 0.022650)
# I_g = 1.010237 IJK ( 0.061968) + -0.000000 ( 0.014096)
# J_g = 1.048136 JJK ( 0.029029) + -0.000000 ( 0.006673)
# H_g = 1.029939 HJK ( 0.018206) + -0.000000 ( 0.004137)
# K_g = 1.019617 KJK ( 0.011830) + 0.000000 ( 0.002720)
# B_g = 0.970950 JJK ( 0.093485) + 0.000000 ( 0.021490)
# V_g = 1.037211 JJK ( 0.068011) + -0.000000 ( 0.015634)
# I_g = 1.058326 JJK ( 0.049635) + -0.000000 ( 0.011410)
# J_g = 1.048136 JJK ( 0.029029) + -0.000000 ( 0.006673)
# H_g = 1.016400 JJK ( 0.019051) + -0.000000 ( 0.004379)
# K_g = 1.019617 JJK ( 0.011830) + 0.000000 ( 0.002720)
# There will be 48 relations, 12 for 4 color minus duplicates.

# %%
cols
# Out:
# ['VI', 'VK', 'IH', 'JK']

# %%
m = {}
me = {}
for c in cols:
    m[c] = del_mc[[f'{mag[i]*2}{c}' for i in range(6)]].iloc[0]
#    c = del_mc[[f'{mag[i]*2}{c}' for i in range(6)]].iloc[1]
    me[c] = del_mc[[f'{mag[i]*2}{c}' for i in range(6)]].iloc[2]
#    ce = del_mc[[f'{mag[i]*2}{c}' for i in range(6)]].iloc[3]
print('Band & rho^{VI}_V (error) &  rho^{VK}_\lambda (error) & rho^{IH}_I (error) & rho^{JK}_J (error) \\\ ')
for i in range(0,6):
    print(f'\t{mag[i]} & ', round(m['VI'][i],7), '(', round(me['VI'][i],7),')', '& ', round(m['VK'][i],7), '(', round(me['VK'][i],7),')', '& ', round(m['IH'][i],7), '(', round(me['IH'][i],7),')', '& ', round(m['JK'][i],7), '(', round(me['JK'][i],7),')', '\\\ ')
# Out:
# Band & rho^{VI}_V (error) &  rho^{VK}_\lambda (error) & rho^{IH}_I (error) & rho^{JK}_J (error) \\
# 	B &  0.7979561 ( 0.077717 ) &  1.0471823 ( 0.086183 ) &  0.7778339 ( 0.1023452 ) &  0.5608983 ( 0.1187498 ) \\
# 	V &  0.8495081 ( 0.0604538 ) &  1.0340639 ( 0.0639825 ) &  0.9035328 ( 0.0820087 ) &  0.7883528 ( 0.1000223 ) \\
# 	I &  0.9085009 ( 0.0367559 ) &  1.0284149 ( 0.0371052 ) &  1.0411626 ( 0.0506481 ) &  1.0102373 ( 0.0619678 ) \\
# 	J &  0.9771342 ( 0.0197859 ) &  1.0152078 ( 0.0180356 ) &  1.0222252 ( 0.0236923 ) &  1.0481358 ( 0.0290294 ) \\
# 	H &  0.9846268 ( 0.0128338 ) &  1.0056609 ( 0.0115645 ) &  1.012254 ( 0.0150778 ) &  1.0299393 ( 0.0182064 ) \\
# 	K &  0.9921777 ( 0.008549 ) &  1.0040536 ( 0.0076139 ) &  1.0106536 ( 0.0098799 ) &  1.019617 ( 0.0118305 ) \\

# %%
def plot_res(col, f='S', s=0, title=''):
    # del-del plot 
    #a,b,c = del_del(col, f)
    fig, axarr = plt.subplots(6, sharex='col',gridspec_kw={'hspace': 0, 'wspace': 0})
    fig = plt.gcf()
    fig.set_size_inches(6, 15)
    for i,ax in enumerate(axarr):
        if f =='S':
            wesen = mag[i]+col
        else: 
            wesen = f+col
        X = residue['r_'+wesen+'_g']
        Y = residue['r_'+mag[i]+'_g']#a[a.columns[2*i+1]]
        ax.scatter(X, Y, label='$%s_g: %f$'%(wesen, del_mc[mag[i]+wesen].iloc[0]), s=data['mod_g'], c = data['EBV'])
        #X = w[mag[i]+color]
#        ax.axhline(y=0.55, color='y', linestyle='--'); 
#        ax.axhline(y=-0.55, color='y', linestyle='--'); 
        #ax.axvline(x=0, color='r', linestyle='--');
        #ax.scatter(X, Y, label='$%s$'%(bands[i]), s=data['mod'], c = 'r', marker='+')
        ax.legend(loc='lower left', prop={'size':9})
        ax.yaxis.tick_right()
        ax.set_ylabel('$\Delta %s$'%(mag[i]))
#        ax.annotate('%s: %f'%(wesen, c.m.iloc[i]), xy =(-1.5, -0.4)) 
    ax.set_xlabel('$\Delta W_\lambda$') 
#    plt.gca().invert_xaxis()
#    ax.yaxis.set_label_coords(-0.1,3) 
    if s==1:
        save(title+col)

c1 = plot_res('VI', s=0,title = 'residueM')
c2 = plot_res('VI', f='V',s=0,title = 'residueS')

# %%
def del_del_plot(x,s=0):
    fig, axarr = plt.subplots(6, sharex='col',gridspec_kw={'hspace': 0, 'wspace': 0})
    fig = plt.gcf()
    fig.set_size_inches(6, 9)
    XM = residue['r_'+x[0]+x]
    for i,ax in enumerate(axarr):
        XS = residue['r_'+mag[i]+x]
        Y = residue['r_'+mag[i]+'_g']
        ax.scatter(XM, Y, label='$%s: %f$'%(mag[i]+x[0]+x[0:2],  del_mc[mag[i]+x[0]+x[0:2]].iloc[0]), s=data['mod_g'], c = data['EBV'])
        ax.scatter(XS, Y, label='$%s: %f$'%(mag[i]*2+x[0:2],  del_mc[2*mag[i]+x[0:2]].iloc[0]), s=data['mod_g'], c = 'r')
        ax.yaxis.tick_right()
        ax.set_ylabel('$\Delta %s$'%(mag[i]))
        ax.legend()
        ax.grid()
    #        ax.annotate('%s: %f'%(wesen, c.m.iloc[i]), xy =(-1.5, -0.4)) 
    ax.set_xlabel('$\Delta$ W,%s'%(x[:2])) 
#    plt.gca().invert_xaxis()
    title = 'del_del' 
    if s==1:
        save(title+x)
    plt.show()

for c in cols:
    del_del_plot(f'{c}_g', s=1)

# %%
for i in range(0,24,6):
    plt.plot([j for j in range(0,6)],del_mc.T.mg[i:i+6], col_lin[int(i/6)])
    ticks = ['B', 'V', 'I', 'J', 'H', 'K']
    plt.xticks([0,1,2,3,4,5],ticks)
    plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Slope comparison of del-del plot

for i in range(0,12,2):
    plt.axhline(y=1, color='k', linestyle='-'); 
    plt.plot([j for j in range(0,6)],dmc[i].m, col_lin[int(i/2)])
    plt.plot([j for j in range(0,6)],dmc[i+1].m, col_das[int(i/2)], label = '$W_{%s}$'%dmc[i].columns[0])
    plt.legend()
plt.show()
for i in range(12,24,2):
    plt.axhline(y=1, color='k', linestyle='-'); 
    plt.plot([j for j in range(0,6)],dmc[i].m, col_lin[int(i/2)-6])
    plt.plot([j for j in range(0,6)],dmc[i+1].m, col_das[int(i/2)-6], label = '$W_{%s}$'%dmc[i].columns[0])
    plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[126], line 5
#       3 for i in range(0,12,2):
#       4     plt.axhline(y=1, color='k', linestyle='-');
# ----> 5     plt.plot([j for j in range(0,6)],dmc[i].m, col_lin[int(i/2)])
#       6     plt.plot([j for j in range(0,6)],dmc[i+1].m, col_das[int(i/2)], label = '$W_{%s}$'%dmc[i].columns[0])
#       7     plt.legend()
#
# NameError: name 'dmc' is not defined

# %%
color = 'VI'
i=0
plot(residue['r_'+mag[i]+color], residue['r_'+bands[i]], mag[i]+color, mag[i], i)
# Out:
# B = 0.942241 BVI ( 0.049062) + 0.000000 ( 0.021998)
# (0.9422412043193481,
#  4.0648342519277876e-17,
#  0    -0.781275
#  1    -0.407253
#  2    -0.422615
#  3     0.203514
#  4    -0.063375
#          ...
#  91    0.201318
#  92   -0.225882
#  93   -0.058422
#  94   -0.772788
#  95   -0.507685
#  Name: r_BVI, Length: 96, dtype: float64,
#  0     0.157766
#  1    -0.015193
#  2     0.170698
#  3     0.060201
#  4    -0.203773
#          ...
#  91   -0.187025
#  92   -0.107003
#  93   -0.079813
#  94   -0.024879
#  95   -0.074849
#  Length: 96, dtype: float64,
#  0.049062175397943907,
#  0.021997937234778206)

# %%
for color in ['BV', 'BI', 'VI', 'VK', 'JK']:
    for i in range(0,6):
        plot(residue['r_'+mag[i]+color], residue['r_'+bands[i]], mag[i]+color, mag[i], i)
# Out:
# B = 0.743589 BBV ( 0.075981) + -0.000000 ( 0.034354)
# V = 0.804267 VBV ( 0.058001) + -0.000000 ( 0.026224)
# I = 0.930135 IBV ( 0.038532) + -0.000000 ( 0.016595)
# J = 0.994563 JBV ( 0.019426) + -0.000000 ( 0.008105)
# H = 1.000775 HBV ( 0.012194) + 0.000000 ( 0.005026)
# K = 1.003577 KBV ( 0.008039) + 0.000000 ( 0.003301)
# B = 0.952904 BBI ( 0.058920) + 0.000000 ( 0.025098)
# V = 0.945271 VBI ( 0.044697) + -0.000000 ( 0.019072)
# I = 0.978142 IBI ( 0.027346) + 0.000000 ( 0.011648)
# J = 1.001862 JBI ( 0.013427) + -0.000000 ( 0.005613)
# H = 1.001635 HBI ( 0.008417) + 0.000000 ( 0.003479)
# K = 1.002353 KBI ( 0.005551) + 0.000000 ( 0.002285)
# B = 0.942241 BVI ( 0.049062) + 0.000000 ( 0.021998)
# V = 0.955978 VVI ( 0.038917) + 0.000000 ( 0.016802)
# I = 0.973235 IVI ( 0.023662) + 0.000000 ( 0.010215)
# J = 0.996924 JVI ( 0.011731) + 0.000000 ( 0.004938)
# H = 0.998114 HVI ( 0.007374) + 0.000000 ( 0.003061)
# K = 0.999565 KVI ( 0.004873) + 0.000000 ( 0.002013)
# B = 1.013762 BVK ( 0.047594) + 0.000000 ( 0.020222)
# V = 1.013188 VVK ( 0.037434) + -0.000000 ( 0.015433)
# I = 1.013536 IVK ( 0.022507) + 0.000000 ( 0.009372)
# J = 1.006402 JVK ( 0.010784) + 0.000000 ( 0.004501)
# H = 1.002373 HVK ( 0.006756) + 0.000000 ( 0.002793)
# K = 1.001569 KVK ( 0.004455) + -0.000000 ( 0.001837)
# B = 0.823542 BJK ( 0.073314) + 0.000000 ( 0.031893)
# V = 0.911877 VJK ( 0.060672) + -0.000000 ( 0.024808)
# I = 1.002703 IJK ( 0.037706) + -0.000000 ( 0.015251)
# J = 1.016702 JJK ( 0.017803) + -0.000000 ( 0.007291)
# H = 1.010205 HJK ( 0.011055) + 0.000000 ( 0.004520)
# K = 1.006806 KJK ( 0.007255) + -0.000000 ( 0.002971)
