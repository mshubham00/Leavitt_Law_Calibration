# %%
files = {}
files['0'] = '58_madore_3.23'
files['1'] = '95_jesper_3.23'
files['2'] = '20_cluster_cruz_3.23'
files['3'] = '30_LMC_3.41'
files['4'] = '32_SMC_VIJK_2.74'
# Out:
#   Cell In[11], line 2
#     files['0'] = '58_madore_3.23'
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Fouque vs mine wesenheit

# %%
import pandas as pd
import matplotlib.pyplot as plt
from data.datamapping import mag, colors, R_
data = pd.read_csv('data/59_madore_3.23/1_prepared/59_wes_data.csv')
fou = pd.read_csv('data/input/table7.csv')
for m in mag:
    plt.plot(data['logP'],data[f'{m}BI_h']-fou['Wbi'],label = f'$\Delta W_{m},BI$')
plt.axhline(y=0, color='gray', linestyle='--')
plt.ylabel(f'Wesenhiet Deviation Wm,S - WB,BI (Fouque)')
plt.legend()
plt.show()

for m in mag:
    plt.plot(data['logP'],data[f'{m}VI_h']-fou['Wvi'],label = f'$\Delta W_{m},VI$')
plt.axhline(y=0, color='gray', linestyle='--')
plt.ylabel(f'Wesenhiet Deviation Wm,S - WB,VI (Fouque)')
plt.legend()
plt.show()
# Deviation between Fouque and Shubham weseheits
dev_bi = data[f'IBI_h']-fou['Wbi']
dev_vi = data[f'IVI_h']-fou['Wvi']
plt.plot(data['logP'],dev_vi, '.',label = f'$\Delta W_I,VI | \sigma = {dev_vi.std() :.3f}$')
plt.plot(data['logP'],dev_bi, '.', label = f'$\Delta W_I,BI | \sigma = {dev_bi.std() :.3f}$')
plt.axhline(y=0, color='gray', linestyle='--')
plt.legend()
plt.ylabel(f'Wesenhiet Deviation from Foque WI,S - WI,F (Fouque)')
plt.show()

# %%
import pandas as pd
def load(x):
    data = pd.read_csv(f'data/{files[str(x)]}/8_result/{files[str(x)][:2]}_merged_data.csv')
    reg = pd.read_csv(f'data/{files[str(x)]}/8_result/{files[str(x)][:2]}_5_result_regression.csv')
    return data, reg

a, b = [], []
for i in range(5):
    x, y=load(i)
    a.append(x)
    b.append(y)
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
name1=[]
name2=[]
for i in range(20):
    for j in range(95):
        if a[2].logP[i] == a[1].logP[j]:
            print(a[1].name[j])
            name1.append(j)
            name2.append(i)

cru = a[2].iloc[name2]
jes = a[1].iloc[name1]

from lvtlaw.a_utils import merge_12
m = merge_12(cru,jes, on=['logP'])
m.style

# %%
# Out:
# <style type="text/css">
# </style>
# <table id="T_48267">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48267_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_48267_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_48267_level0_col2" class="col_heading level0 col2" >logP</th>
#       <th id="T_48267_level0_col3" class="col_heading level0 col3" >EBV</th>
#       <th id="T_48267_level0_col4" class="col_heading level0 col4" >mplx</th>
#       <th id="T_48267_level0_col5" class="col_heading level0 col5" >M_B_p</th>
#       <th id="T_48267_level0_col6" class="col_heading level0 col6" >M_V_p</th>
#       <th id="T_48267_level0_col7" class="col_heading level0 col7" >M_I_p</th>
#       <th id="T_48267_level0_col8" class="col_heading level0 col8" >M_J_p</th>
#       <th id="T_48267_level0_col9" class="col_heading level0 col9" >M_H_p</th>
#       <th id="T_48267_level0_col10" class="col_heading level0 col10" >M_K_p</th>
#       <th id="T_48267_level0_col11" class="col_heading level0 col11" >M_B0_p</th>
#       <th id="T_48267_level0_col12" class="col_heading level0 col12" >M_V0_p</th>
#       <th id="T_48267_level0_col13" class="col_heading level0 col13" >M_I0_p</th>
#       <th id="T_48267_level0_col14" class="col_heading level0 col14" >M_J0_p</th>
#       <th id="T_48267_level0_col15" class="col_heading level0 col15" >M_H0_p</th>
#       <th id="T_48267_level0_col16" class="col_heading level0 col16" >M_K0_p</th>
#       <th id="T_48267_level0_col17" class="col_heading level0 col17" >BBV_p</th>
#       <th id="T_48267_level0_col18" class="col_heading level0 col18" >BBI_p</th>
#       <th id="T_48267_level0_col19" class="col_heading level0 col19" >BBJ_p</th>
#       <th id="T_48267_level0_col20" class="col_heading level0 col20" >BBH_p</th>
#       <th id="T_48267_level0_col21" class="col_heading level0 col21" >BBK_p</th>
#       <th id="T_48267_level0_col22" class="col_heading level0 col22" >BVI_p</th>
#       <th id="T_48267_level0_col23" class="col_heading level0 col23" >BVJ_p</th>
#       <th id="T_48267_level0_col24" class="col_heading level0 col24" >BVH_p</th>
#       <th id="T_48267_level0_col25" class="col_heading level0 col25" >BVK_p</th>
#       <th id="T_48267_level0_col26" class="col_heading level0 col26" >BIJ_p</th>
#       <th id="T_48267_level0_col27" class="col_heading level0 col27" >BIH_p</th>
#       <th id="T_48267_level0_col28" class="col_heading level0 col28" >BIK_p</th>
#       <th id="T_48267_level0_col29" class="col_heading level0 col29" >BJH_p</th>
#       <th id="T_48267_level0_col30" class="col_heading level0 col30" >BJK_p</th>
#       <th id="T_48267_level0_col31" class="col_heading level0 col31" >BHK_p</th>
#       <th id="T_48267_level0_col32" class="col_heading level0 col32" >VBV_p</th>
#       <th id="T_48267_level0_col33" class="col_heading level0 col33" >VBI_p</th>
#       <th id="T_48267_level0_col34" class="col_heading level0 col34" >VBJ_p</th>
#       <th id="T_48267_level0_col35" class="col_heading level0 col35" >VBH_p</th>
#       <th id="T_48267_level0_col36" class="col_heading level0 col36" >VBK_p</th>
#       <th id="T_48267_level0_col37" class="col_heading level0 col37" >VVI_p</th>
#       <th id="T_48267_level0_col38" class="col_heading level0 col38" >VVJ_p</th>
#       <th id="T_48267_level0_col39" class="col_heading level0 col39" >VVH_p</th>
#       <th id="T_48267_level0_col40" class="col_heading level0 col40" >VVK_p</th>
#       <th id="T_48267_level0_col41" class="col_heading level0 col41" >VIJ_p</th>
#       <th id="T_48267_level0_col42" class="col_heading level0 col42" >VIH_p</th>
#       <th id="T_48267_level0_col43" class="col_heading level0 col43" >VIK_p</th>
#       <th id="T_48267_level0_col44" class="col_heading level0 col44" >VJH_p</th>
#       <th id="T_48267_level0_col45" class="col_heading level0 col45" >VJK_p</th>
#       <th id="T_48267_level0_col46" class="col_heading level0 col46" >VHK_p</th>
#       <th id="T_48267_level0_col47" class="col_heading level0 col47" >IBV_p</th>
#       <th id="T_48267_level0_col48" class="col_heading level0 col48" >IBI_p</th>
#       <th id="T_48267_level0_col49" class="col_heading level0 col49" >IBJ_p</th>
#       <th id="T_48267_level0_col50" class="col_heading level0 col50" >IBH_p</th>
#       <th id="T_48267_level0_col51" class="col_heading level0 col51" >IBK_p</th>
#       <th id="T_48267_level0_col52" class="col_heading level0 col52" >IVI_p</th>
#       <th id="T_48267_level0_col53" class="col_heading level0 col53" >IVJ_p</th>
#       <th id="T_48267_level0_col54" class="col_heading level0 col54" >IVH_p</th>
#       <th id="T_48267_level0_col55" class="col_heading level0 col55" >IVK_p</th>
#       <th id="T_48267_level0_col56" class="col_heading level0 col56" >IIJ_p</th>
#       <th id="T_48267_level0_col57" class="col_heading level0 col57" >IIH_p</th>
#       <th id="T_48267_level0_col58" class="col_heading level0 col58" >IIK_p</th>
#       <th id="T_48267_level0_col59" class="col_heading level0 col59" >IJH_p</th>
#       <th id="T_48267_level0_col60" class="col_heading level0 col60" >IJK_p</th>
#       <th id="T_48267_level0_col61" class="col_heading level0 col61" >IHK_p</th>
#       <th id="T_48267_level0_col62" class="col_heading level0 col62" >JBV_p</th>
#       <th id="T_48267_level0_col63" class="col_heading level0 col63" >JBI_p</th>
#       <th id="T_48267_level0_col64" class="col_heading level0 col64" >JBJ_p</th>
#       <th id="T_48267_level0_col65" class="col_heading level0 col65" >JBH_p</th>
#       <th id="T_48267_level0_col66" class="col_heading level0 col66" >JBK_p</th>
#       <th id="T_48267_level0_col67" class="col_heading level0 col67" >JVI_p</th>
#       <th id="T_48267_level0_col68" class="col_heading level0 col68" >JVJ_p</th>
#       <th id="T_48267_level0_col69" class="col_heading level0 col69" >JVH_p</th>
#       <th id="T_48267_level0_col70" class="col_heading level0 col70" >JVK_p</th>
#       <th id="T_48267_level0_col71" class="col_heading level0 col71" >JIJ_p</th>
#       <th id="T_48267_level0_col72" class="col_heading level0 col72" >JIH_p</th>
#       <th id="T_48267_level0_col73" class="col_heading level0 col73" >JIK_p</th>
#       <th id="T_48267_level0_col74" class="col_heading level0 col74" >JJH_p</th>
#       <th id="T_48267_level0_col75" class="col_heading level0 col75" >JJK_p</th>
#       <th id="T_48267_level0_col76" class="col_heading level0 col76" >JHK_p</th>
#       <th id="T_48267_level0_col77" class="col_heading level0 col77" >HBV_p</th>
#       <th id="T_48267_level0_col78" class="col_heading level0 col78" >HBI_p</th>
#       <th id="T_48267_level0_col79" class="col_heading level0 col79" >HBJ_p</th>
#       <th id="T_48267_level0_col80" class="col_heading level0 col80" >HBH_p</th>
#       <th id="T_48267_level0_col81" class="col_heading level0 col81" >HBK_p</th>
#       <th id="T_48267_level0_col82" class="col_heading level0 col82" >HVI_p</th>
#       <th id="T_48267_level0_col83" class="col_heading level0 col83" >HVJ_p</th>
#       <th id="T_48267_level0_col84" class="col_heading level0 col84" >HVH_p</th>
#       <th id="T_48267_level0_col85" class="col_heading level0 col85" >HVK_p</th>
#       <th id="T_48267_level0_col86" class="col_heading level0 col86" >HIJ_p</th>
#       <th id="T_48267_level0_col87" class="col_heading level0 col87" >HIH_p</th>
#       <th id="T_48267_level0_col88" class="col_heading level0 col88" >HIK_p</th>
#       <th id="T_48267_level0_col89" class="col_heading level0 col89" >HJH_p</th>
#       <th id="T_48267_level0_col90" class="col_heading level0 col90" >HJK_p</th>
#       <th id="T_48267_level0_col91" class="col_heading level0 col91" >HHK_p</th>
#       <th id="T_48267_level0_col92" class="col_heading level0 col92" >KBV_p</th>
#       <th id="T_48267_level0_col93" class="col_heading level0 col93" >KBI_p</th>
#       <th id="T_48267_level0_col94" class="col_heading level0 col94" >KBJ_p</th>
#       <th id="T_48267_level0_col95" class="col_heading level0 col95" >KBH_p</th>
#       <th id="T_48267_level0_col96" class="col_heading level0 col96" >KBK_p</th>
#       <th id="T_48267_level0_col97" clas

# %%
import matplotlib.pyplot as plt
band = 'I'
col = 'JK'
plt.plot(m['logP'], m[f'M_{band}_g'] - m[f'{band}S0VI_g'], '.')

# %%
import pandas as pd
from data.datamapping import mag, col_lin

reg = pd.read_csv(f'data/{files[str(1)]}/3_deldel/{files[str(1)][:2]}_del_slope_intercept.csv')

for m in mag:
    bi = reg[f'{m}0{m}BI']
    vi = reg[f'{m}0{m}VI']
    ih = reg[f'{m}0{m}IH']
    jk = reg[f'{m}0{m}JK']
    print(f"\t{m} & {bi.iloc[0] : .3f} ($\pm$ {bi.iloc[2] : .3f}) & {vi.iloc[0] : .3f} ($\pm$ {vi.iloc[2] : .3f}) & {ih.iloc[0] : .3f} ($\pm$ {ih.iloc[2] : .3f}) & {jk.iloc[0] : .3f} ($\pm$ {jk.iloc[2] : .3f}) \\\\")
# Out:
# 	B &  0.797 ($\pm$  0.088) &  0.819 ($\pm$  0.075) &  0.791 ($\pm$  0.094) &  0.619 ($\pm$  0.111) \\
# 	V &  0.818 ($\pm$  0.066) &  0.847 ($\pm$  0.060) &  0.882 ($\pm$  0.079) &  0.778 ($\pm$  0.095) \\
# 	I &  0.906 ($\pm$  0.041) &  0.907 ($\pm$  0.036) &  1.022 ($\pm$  0.049) &  0.993 ($\pm$  0.060) \\
# 	J &  0.979 ($\pm$  0.022) &  0.976 ($\pm$  0.019) &  1.013 ($\pm$  0.023) &  1.037 ($\pm$  0.028) \\
# 	H &  0.986 ($\pm$  0.014) &  0.984 ($\pm$  0.013) &  1.007 ($\pm$  0.015) &  1.023 ($\pm$  0.018) \\
# 	K &  0.994 ($\pm$  0.009) &  0.992 ($\pm$  0.008) &  1.007 ($\pm$  0.010) &  1.015 ($\pm$  0.012) \\

# %%
for i, m in enumerate(mag):
    print(f"\t{m} &  {reg[m+col].iloc[0] : .3f} ($\pm${reg[m+col].iloc[2] : .3f}) & {reg[m+col].iloc[1] : .3f} ($\pm${reg[m+col].iloc[3] : .3f}) \\\\")

# %%
PLWreg = pd.read_csv(f'data/{files[str(1)]}/2_PLW/{files[str(1)][:2]}_5_regression.csv')

col='JK'
for i, m in enumerate(mag):
    print(f"\t{m},{col} &  {reg[m+col].iloc[0] : .3f} ($\pm${reg[m+col].iloc[2] : .3f}) & {reg[m+col].iloc[1] : .3f} ($\pm${reg[m+col].iloc[3] : .3f}) \\\\")
# Out:
# 	B,JK &  -3.269 ($\pm$ 0.089) & -6.517 ($\pm$ 0.027) \\
# 	V,JK &  -3.338 ($\pm$ 0.082) & -6.468 ($\pm$ 0.024) \\
# 	I,JK &  -3.219 ($\pm$ 0.081) & -6.265 ($\pm$ 0.024) \\
# 	J,JK &  -3.099 ($\pm$ 0.082) & -5.952 ($\pm$ 0.024) \\
# 	H,JK &  -3.113 ($\pm$ 0.081) & -6.054 ($\pm$ 0.024) \\
# 	K,JK &  -3.099 ($\pm$ 0.082) & -5.952 ($\pm$ 0.024) \\

# %%
for i, m in enumerate(mag):
    print(f"\t{m} &  {b[1][m+'0'].iloc[0] : .3f} ($\pm${b[1][m+'0'].iloc[2] : .3f}) & {b[1][m+'0'].iloc[1] : .3f} ($\pm${b[1][m+'0'].iloc[3] : .3f}) \\\\")
# Out:
# 	B &  -1.855 ($\pm$ 0.110) & -3.221 ($\pm$ 0.033) \\
# 	V &  -2.259 ($\pm$ 0.098) & -3.951 ($\pm$ 0.029) \\
# 	I &  -2.563 ($\pm$ 0.093) & -4.735 ($\pm$ 0.028) \\
# 	J &  -2.784 ($\pm$ 0.088) & -5.218 ($\pm$ 0.026) \\
# 	H &  -2.917 ($\pm$ 0.084) & -5.598 ($\pm$ 0.025) \\
# 	K &  -2.971 ($\pm$ 0.084) & -5.653 ($\pm$ 0.025) \\

# %%
from data.datamapping import mag, col_lin
ab=0
col='VI'
f='S'
b[0][[f'{m}{ab}{col}{f}' for m in mag]].style
# Out:
# <style type="text/css">
# </style>
# <table id="T_86ce1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86ce1_level0_col0" class="col_heading level0 col0" >B0VIS</th>
#       <th id="T_86ce1_level0_col1" class="col_heading level0 col1" >V0VIS</th>
#       <th id="T_86ce1_level0_col2" class="col_heading level0 col2" >I0VIS</th>
#       <th id="T_86ce1_level0_col3" class="col_heading level0 col3" >J0VIS</th>
#       <th id="T_86ce1_level0_col4" class="col_heading level0 col4" >H0VIS</th>
#       <th id="T_86ce1_level0_col5" class="col_heading level0 col5" >K0VIS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86ce1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_86ce1_row0_col0" class="data row0 col0" >-2.269185</td>
#       <td id="T_86ce1_row0_col1" class="data row0 col1" >-2.663342</td>
#       <td id="T_86ce1_row0_col2" class="data row0 col2" >-2.978232</td>
#       <td id="T_86ce1_row0_col3" class="data row0 col3" >-3.194594</td>
#       <td id="T_86ce1_row0_col4" class="data row0 col4" >-3.330394</td>
#       <td id="T_86ce1_row0_col5" class="data row0 col5" >-3.374300</td>
#     </tr>
#     <tr>
#       <th id="T_86ce1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_86ce1_row1_col0" class="data row1 col0" >-3.214709</td>
#       <td id="T_86ce1_row1_col1" class="data row1 col1" >-3.944908</td>
#       <td id="T_86ce1_row1_col2" class="data row1 col2" >-4.706862</td>
#       <td id="T_86ce1_row1_col3" class="data row1 col3" >-5.258384</td>
#       <td id="T_86ce1_row1_col4" class="data row1 col4" >-5.558797</td>
#       <td id="T_86ce1_row1_col5" class="data row1 col5" >-5.659213</td>
#     </tr>
#     <tr>
#       <th id="T_86ce1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_86ce1_row2_col0" class="data row2 col0" >0.042927</td>
#       <td id="T_86ce1_row2_col1" class="data row2 col1" >0.028905</td>
#       <td id="T_86ce1_row2_col2" class="data row2 col2" >0.030740</td>
#       <td id="T_86ce1_row2_col3" class="data row2 col3" >0.027190</td>
#       <td id="T_86ce1_row2_col4" class="data row2 col4" >0.022027</td>
#       <td id="T_86ce1_row2_col5" class="data row2 col5" >0.023236</td>
#     </tr>
#     <tr>
#       <th id="T_86ce1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_86ce1_row3_col0" class="data row3 col0" >0.012804</td>
#       <td id="T_86ce1_row3_col1" class="data row3 col1" >0.008621</td>
#       <td id="T_86ce1_row3_col2" class="data row3 col2" >0.009169</td>
#       <td id="T_86ce1_row3_col3" class="data row3 col3" >0.008110</td>
#       <td id="T_86ce1_row3_col4" class="data row3 col4" >0.006570</td>
#       <td id="T_86ce1_row3_col5" class="data row3 col5" >0.006930</td>
#     </tr>
#   </tbody>
# </table>

# %%
riess = pd.read_csv('data/18_riess/18_true_abs_data.csv')
riess
# Out:
#     Unnamed: 0   name      logP    EBV        plx    M_B0_g    M_V0_g  \
# 0            0  CFCas  0.687994  0.553  12.252555 -2.254463 -2.910745
# 1            1  CSVel  0.771201  0.737  12.547220 -2.616688 -3.218730
# 2            2  CVMon  0.730685  0.722  10.978801 -2.437799 -3.005861
# 3            3  EVSct  0.490098  0.655  11.225259 -2.706761 -3.196909
# 4            4  GHLup  0.967448  0.347  10.222618 -2.846879 -3.706428
# 5            5  QZNor  0.578244  0.263  11.425521 -2.782353 -3.406011
# 6            6  RSOri  0.878917  0.352  11.001908 -3.115326 -3.724868
# 7            7   SNor  0.989194  0.179   9.728963 -3.111366 -3.878133
# 8            8  STTau  0.605768  0.368  10.141119 -2.632237 -3.110759
# 9            9  SVVul  1.652569  0.462  11.815498 -5.070358 -6.094758
# 10          10  TWNor  1.032868  1.157  11.971017 -3.236631 -4.007127
# 11          11   USgr  0.828997  0.402   8.923041 -2.838023 -3.531501
# 12          12   VCen  0.739882  0.294   9.197433 -2.736436 -3.313053
# 13          13   VLac  0.697493  0.335  11.372475 -2.973960 -3.533525
# 14          14  AAGem  1.053181  0.309  12.300635 -2.799106 -3.569705
# 15          15   XLac  0.735997  0.336  11.290871 -3.406587 -3.971151
# 16          16   XPup  1.414321  0.421  11.818071 -3.897448 -4.670901
# 17          17   YSct  1.014575  0.757  11.143930 -3.153024 -3.957040
#
#       M_I0_g    M_J0_g    M_H0_g    M_K0_g
# 0  -3.647558 -4.073122 -4.443855 -4.499111
# 1  -3.926570 -4.402329 -4.744093 -4.812501
# 2  -3.780693 -4.255762 -4.609903 -4.680316
# 3  -3.888575 -4.179029 -4.437192 -4.449022
# 4  -4.540071 -5.057895 -5.465485 -5.542995
# 5  -4.077011 -4.537572 -4.846279 -4.907611
# 6  -4.440180 -4.844901 -5.189698 -5.220207
# 7  -4.653490 -5.168789 -5.558612 -5.635765
# 8  -3.725812 -4.136202 -4.458263 -4.494567
# 9  -7.052792 -7.583238 -7.995597 -8.063077
# 10 -4.956180 -5.556253 -5.953434 -6.025733
# 11 -4.286504 -4.715191 -5.065062 -5.123557
# 12 -3.978802 -4.401722 -4.741315 -4.801438
# 13 -4.164361 -4.567434 -4.897326 -4.914239
# 14 -4.326461 -4.858071 -5.281285 -5.313405
# 15 -4.633721 -4.999772 -5.330306 -5.374019
# 16 -5.537848 -6.035141 -6.464200 -6.548891
# 17 -4.789557 -5.279902 -5.690495 -5.743898

# %%
import matplotlib.pyplot as plt
d = ['h', 'g', 'p', 'l', 's']
band = 'K'
for i in range(5):
    plt.plot(a[i]['logP']-1, a[i][f'{band}S0VI_{d[i]}'], '.', label = f'{files[str(i)]}')
#plt.plot(riess['logP']-1, riess[f'M_{band}0_g'] , 'o', label = f'18_riess')
plt.legend()
plt.show()

# %%
ab=''
for i in range(3):
    sl = b[i][[f'{m}{ab}{col}{f}' for m in mag]].iloc[0]
    plt.plot([x for x in range(len(mag))], sl, col_lin[i], label = files[str(i)])
    sl = b[i][[f'{m}0{col}{f}' for m in mag]].iloc[0]
    plt.plot([x for x in range(len(mag))], sl, '--', label = files[str(i)])
#    inter = b[i][[f'{m}{ab}{col}{f}' for m in mag]].iloc[1]
#    plt.plot([x for x in range(len(mag))], inter, col_lin[i], label = files[str(i)])
    #plt.ylim(-0.2, 0.2)
#    plt.axhline(y=np.mean(rd), color='gray', linestyle='--')
    plt.legend()
plt.show()
